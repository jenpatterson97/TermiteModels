# %% [markdown]
# ### Main logic

# %%
from sklearn.svm import LinearSVC
import random
from random import randrange
import pickle
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC

# %%
import numpy as np
import re
from readability import Readability

# %%
topic_model = pickle.load(open('topicmodel.sav', 'rb'))
topic_vectorizer = pickle.load(open('topicvectorizer.sav', 'rb'))

# %%
testfile = open("testpolicy.txt", 'r')
body = testfile.read()


# preprocess data 

def get_lines(body):
    output_lines = []
    #body = body.replace('\n', '. ')
    lines = body.split('. ')
    for line in lines:
        if len(line) > 20:
            output_lines.append(line)
        
    return output_lines

# %%
def super_topic_classifier(line):
    
    vectorized = topic_vectorizer.transform([line])
    topic = topic_model.predict(vectorized)
    conf = topic_model.predict_proba(vectorized)
    
    return topic, conf

# %%
all_subclasses= [
    ["sub1_1", "sub1_2", "sub1_3", "sub1_4", "sub1_5", "sub1_6", "sub1_7"],
    ["sub2_1", "sub2_2", "sub2_3", "sub2_4", "sub2_5", "sub2_6", "sub2_7", "sub2_8","sub2_9"],
    ["sub3_1", "sub3_2", "sub3_3", "sub3_4", "sub3_5", "sub3_6", "sub3_7", "sub3_8", "sub3_9","sub3_10"],
    ["sub4_1", "sub4_2", "sub4_3", "sub4_4", "sub4_5", "sub4_6"],
    ["sub5_1", "sub5_2", "sub5_3", "sub5_4", "sub5_5"],
    ["sub6_1", "sub6_2", "sub6_3", "sub6_4"]
]


def subtopic_classification(topic_lines, topic_num, subclass):
    
    foldername = "./topic" + str(topic_num) + "models"
    model_filename = foldername + '/' + subclass + "model.sav"
    vectorizer_filename = foldername + '/' + subclass + "vectorizer.sav"
    
    ## what kind of model logic
    
    subtopic_model = pickle.load(open(model_filename, 'rb'))
    subtopic_vectorizer = pickle.load(open(vectorizer_filename, 'rb'))
    
    vectorized = subtopic_vectorizer.transform(topic_lines)
    

    #labels = subtopic_model.predict(vectorized)
    confs = subtopic_model.predict_proba(vectorized)
    
    
    confs_in_pos_class = confs[:,1]
    
    return confs_in_pos_class

    

def topic_classifier(topic_lines, topic_num, scores):

    
    subclasses = all_subclasses[topic_num-1]
    
    
    for subclass in subclasses: 

        if len(topic_lines) > 0:
            max_conf = 0
            extract = ""

            items = [x[2] for x in topic_lines]


            confs = subtopic_classification(items, topic_num, subclass)

            max_index = np.argmax(confs)
            max_conf = confs[max_index]
            extract = items[max_index]

            scores[subclass + "_score"] = max_conf
            scores[subclass + "_extract"] = extract.replace('\n',' ')
        else:
            scores[subclass + "_score"] = 0
            scores[subclass + "_extract"] = "No information found."

# %%
def get_lexicon_score(body):
    r = Readability(body)
    

    d = r.dale_chall()
    print(d.score)
    print(d.grade_levels)



get_lexicon_score(body)
# Out:
# 10.433202828443035
# ['college_graduate']

# %%
def main(body):
    
    scores = {}
    
    lines = get_lines(body)

    lexicon_score = get_lexicon_score(body)
    scores[lexicon_score] = lexicon_score
    topic1 = []
    topic2 = []
    topic3 = []
    topic4 = []
    topic5 = []
    topic6 = []
    irr = []
    
    
    
    for line in lines: 
        
        raw_topic, raw_conf = super_topic_classifier(line)
        topic, conf = raw_topic[0]+1, raw_conf[0][int(raw_topic[0])]
        
        if conf > .3:
            if str(topic) == '1':
                topic1.append([topic, conf, line])

            if str(topic) == '2':
                topic2.append([topic, conf, line])

            if str(topic) == '3':
                topic3.append([topic, conf, line])

            if str(topic) == '4':
                topic4.append([topic, conf, line])

            if str(topic) == '5':
                topic5.append([topic, conf, line])

            if str(topic) == '6':
                topic6.append([topic, conf, line])
        else:
            irr.append(line)
            
    
    topics = [topic1,topic2,topic3,topic4,topic5,topic6]

    counter = 1
    for topic in topics:
        topic_classifier(topic, counter, scores)
        counter += 1
        
    return scores

# %%
scores = main(body)

# %%
scores
# Out:
# {'sub1_1_score': 0.6753785499698174,
#  'sub1_1_extract': 'We are not responsible for any circumvention of any unauthorized access to your information',
#  'sub1_2_score': 0.004956371623434614,
#  'sub1_2_extract': 'We are not responsible for any circumvention of any unauthorized access to your information',
#  'sub1_3_score': 0.04854742982783997,
#  'sub1_3_extract': 'We are not responsible for any circumvention of any unauthorized access to your information',
#  'sub1_4_score': 0.001358598526876545,
#  'sub1_4_extract': 'We are not responsible for any circumvention of any unauthorized access to your information',
#  'sub1_5_score': 0.001443944282379174,
#  'sub1_5_extract': 'We are not responsible for any circumvention of any unauthorized access to your information',
#  'sub1_6_score': 0.20623267375578322,
#  'sub1_6_extract': 'We are not responsible for any circumvention of any unauthorized access to your information',
#  'sub1_7_score': 0.21923236356533649,
#  'sub1_7_extract': 'We are not responsible for any circumvention of any unauthorized access to your information',
#  'sub2_1_score': 0.9999324412792436,
#  'sub2_1_extract': 'In some instances, you may be eligible to (a) request that 2U export a full listing of your personal information in a commonly used electronic form (b) withdraw your consent to 2U for processing your personal information; and (c) request that 2U restrict processing or delete your information',
#  'sub2_2_score': 0.0842760883856372,
#  'sub2_2_extract': 'In some instances, you may be eligible to (a) request that 2U export a full listing of your personal information in a commonly used electronic form (b) withdraw your consent to 2U for processing your personal information; and (c) request that 2U restrict processing or delete your information',
#  'sub2_3_score': 0.4052357798559367,
#  'sub2_3_extract': 'In some instances, you may be eligible to (a) request that 2U export a full listing of your personal information in a commonly used electronic form (b) withdraw your consent to 2U for processing your personal information; and (c) request that 2U restrict processing or delete your information',
#  'sub2_4_score': 0.3094801538980137,
#  'sub2_4_extract': 'In some instances, you may be eligible to (a) request that 2U export a full listing of your personal information in a commonly used electronic form (b) withdraw your consent to 2U for processing your personal information; and (c) request that 2U restrict processing or delete your information',
#  'sub2_5_score': 0.04866726871613156,
#  'sub2_5_extract': 'In some instances, you may be eligible to (a) request that 2U export a full listing of your personal information in a commonly used electronic form (b) withdraw your consent to 2U for processing your personal information; and (c) request that 2U restrict processing or delete your information',
#  'sub2_6_score': 0.11739571257900654,
#  'sub2_6_extract': 'In some instances, you may be eligible to (a) request that 2U export a full listing of your personal information in a commonly used electronic form (b) withdraw your consent to 2U for processing your personal information; and (c) request that 2U restrict processing or delete your information',
#  'sub2_7_score': 0.006459285554562984,
#  'sub2_7_extract': 'In some instances, you may be eligible to (a) request that 2U export a full listing of your personal information in a commonly used electronic form (b) withdraw your consent to 2U for processing your personal information; and (c) request that 2U restrict processing or delete your information',
#  'sub2_8_score': 0.00020089422628776705,
#  'sub2_8_extract': 'In some instances, you may be eligible to (a) request that 2U export a full listing of your personal information in a commonly used electronic form (b) withdraw your consent to 2U for processing your personal information; and (c) request that 2U restrict processing or delete your information',
#  'sub2_9_score': 0.0008421228305544674,
#  'sub2_9_extract': 'In some instances, you may be eligible to (a) request that 2U export a full listing of your personal information in a commonly used electronic form (b) withdraw your consent to 2U for processing your personal information; and (c) request that 2U restrict processing or delete your information',
#  'sub3_1_score': 0.9999589929244523,
#  'sub3_1_extract': 'The information we collect may include your name, address, e-mail address, telephone number, Your Content (as described further in the Terms of Use), the content of any communications to us, including the comments you share in the LMS, or any other information you upload or provide to us through the LMS.  Information Automatically Collected  We may use a variety of technologies such as cookies, pixel tags, web beacons, web server logs, and other similar technologies to collect certain information about your use of the LMS and interactions with our emails, and to allow us to keep track of analytics and certain statistical information.  For example, we may automatically collect information from your computer or other device used to access the LMS, including your internet protocol address (“IP address”), browser type, operating system, device identifier, device model, software version, or mobile or ISP carrier information',
#  'sub3_2_score': 0.005194670490604008,
#  'sub3_2_extract': 'Some of these service providers may use technology such as cookies, web beacons, pixel tags, log files, or Flash cookies to receive, collect, and store information.  Information Collected from Other Sources  We may obtain information about you from other sources, including those that you may use to connect or integrate into the LMS, such as Google Cloud',
#  'sub3_3_score': 0.00129899357910458,
#  'sub3_3_extract': 'You may adjust your browser or operating system settings to limit certain tracking or to decline cookies; however, if you do so, you may be unable to access certain areas or use certain features of the LMS',
#  'sub3_4_score': 0.04212547969703937,
#  'sub3_4_extract': 'You may adjust your browser or operating system settings to limit certain tracking or to decline cookies; however, if you do so, you may be unable to access certain areas or use certain features of the LMS',
#  'sub3_5_score': 0.0009551401792481824,
#  'sub3_5_extract': 'Check the “Help” menu of your browser or operating system to learn how to delete and/or disable your browser or operating system from receiving cookies or controlling your tracking preferences',
#  'sub3_6_score': 0.11226570554328881,
#  'sub3_6_extract': 'Check the “Help” menu of your browser or operating system to learn how to delete and/or disable your browser or operating system from receiving cookies or controlling your tracking preferences',
#  'sub3_7_score': 0.9920250220551758,
#  'sub3_7_extract': 'The information we collect may include your name, address, e-mail address, telephone number, Your Content (as described further in the Terms of Use), the content of any communications to us, including the comments you share in the LMS, or any other information you upload or provide to us through the LMS.  Information Automatically Collected  We may use a variety of technologies such as cookies, pixel tags, web beacons, web server logs, and other similar technologies to collect certain information about your use of the LMS and interactions with our emails, and to allow us to keep track of analytics and certain statistical information.  For example, we may automatically collect information from your computer or other device used to access the LMS, including your internet protocol address (“IP address”), browser type, operating system, device identifier, device model, software version, or mobile or ISP carrier information',
#  'sub3_8_score': 0.6325041692843253,
#  'sub3_8_extract': 'On your mobile device, you can adjust your privacy and advertising settings to limit your tracking for advertising or control whether you receive more relevant advertising.  Our systems may not respond to Do Not Track requests or headers from some or all browsers',
#  'sub3_9_score': 0.0017474085164985496,
#  'sub3_9_extract': 'Check the “Help” menu of your browser or operating system to learn how to delete and/or disable your browser or operating system from receiving cookies or controlling your tracking preferences',
#  'sub3_10_score': 0.014180420296659925,
#  'sub3_10_extract': 'Any data that 2U accesses, uses, stores, or otherwise shares as part of that integration will comply with this Privacy Policy.  Combination of Information  We may combine the information we receive from and about you, including information you provide to us and information we automatically collect through the LMS, as well as information collected from third party sources (including your professors) to help us provide services through the LMS, tailor our communications to you, and to improve the LMS.  Tracking Options and California Do Not Track Disclosures  Certain parts of the LMS require cookies',
#  'sub4_1_score': 0.9871494294845296,
#  'sub4_1_extract': 'Learn more about the use of cookies or other tracking or retargeting technologies and your choices regarding the use of information collected this way by certain Service Providers (as defined below).  How We Use Your Information  In its capacity as a technology service provider to the School, 2U may use the information it collects from and about you:  To provide our services, including the set-up and management of accounts and profiles; To develop new products or services and to conduct analysis to enhance current products and services; To communicate with you related to your use of the LMS or to your participation in the Program',
#  'sub4_2_score': 0.4645394500802143,
#  'sub4_2_extract': 'Thank you for participating in the The University of California, Berkeley, School of Information (the “School”) Master of Information and Data Science online program (the “Program”)',
#  'sub4_3_score': 0.7308723660646033,
#  'sub4_3_extract': 'We ask that you not share your password with anyone',
#  'sub4_4_score': 0.0010930755586084442,
#  'sub4_4_extract': 'We are not responsible for the practices of such sites or applications, and we encourage you to read and fully understand their privacy policies.  Children’s Privacy  We do not direct the LMS to, nor do we knowingly collect any personal information from, children under 13.  Accessing and Managing Your Personal Information  You may access and/or update your personal information through your user profile',
#  'sub4_5_score': 0.3175525347594096,
#  'sub4_5_extract': 'For example, we may collect your information when you register for the LMS, submit information through the LMS, request information from us, or otherwise contact us',
#  'sub4_6_score': 0.028156161010200062,
#  'sub4_6_extract': 'If you choose not to provide this personal information or request that 2U delete or restrict processing of this personal information, you may not be able to participate in the Program, and we may not be able to provide you with other services, including those provided through the LMS or advertised about the Program.  To the extent the above rights apply in your country, they may be limited in some situations, for example, where 2U is under a legal requirement to retain certain information',
#  'sub5_1_score': 0.9984564229108277,
#  'sub5_1_extract': 'These service providers are only provided access to your information to the extent necessary to process your information and/or provide services to 2U, and may not use or share your information for any other purposes. Legal Matters; Safety: We may access and disclose your information to satisfy any applicable law, regulation, legal process, or governmental request, or in connection with an investigation on matters related to public safety, as permitted by law, or otherwise as required by law',
#  'sub5_2_score': 0.1868970379053411,
#  'sub5_2_extract': 'For example, we provide Google Analytics with de-identified data so that they may provide us with a better understanding of visitors’ interactions with the LMS, including actions a visitor takes while accessing the LMS or sites to which a visitor navigates after leaving the LMS',
#  'sub5_3_score': 0.9995993446178142,
#  'sub5_3_extract': 'These service providers are only provided access to your information to the extent necessary to process your information and/or provide services to 2U, and may not use or share your information for any other purposes. Legal Matters; Safety: We may access and disclose your information to satisfy any applicable law, regulation, legal process, or governmental request, or in connection with an investigation on matters related to public safety, as permitted by law, or otherwise as required by law',
#  'sub5_4_score': 0.09029262978540849,
#  'sub5_4_extract': 'Certain personal information, however, is necessary for us to provide information to you about the Program or to provide services to you through the LMS or otherwise',
#  'sub5_5_score': 0.210154635991532,
#  'sub5_5_extract': 'You may not opt out of receiving such communications while participating in the Program; To integrate your use of the LMS with select services provided to you by Google; To personalize your experience on the LMS and help us better respond to your individual needs; To review the usage and operations of the LMS and to analyze and improve the LMS (we continually strive to improve the LMS based on the information and feedback we receive from you); To respond to your inquiries or contact and communicate with you when necessary; To protect the security of the LMS; and As otherwise described at the point of collection or for purposes which you expressly permit us to use the information. We will retain your personal information for as long as necessary to provide you with the services through the Website or to otherwise administer and maintain the services and our Website.  How We Disclose Your Information  2U may share your information with other entities or individuals outside of 2U in the following limited circumstances:  School: We may share your information with the School in order to process your information, track your participation in the Program, and/or provide our services to the School. Service Providers: We may share information with our service providers that provide business, professional, or technical support functions for us',
#  'sub6_1_score': 0.9998473891962715,
#  'sub6_1_extract': 'This privacy policy (the “Privacy Policy”) describes the types of information that 2U, Inc',
#  'sub6_2_score': 0.2491701483053109,
#  'sub6_2_extract': 'When we do, we will post the change(s) on the LMS',
#  'sub6_3_score': 0.8947575651581485,
#  'sub6_3_extract': 'In the event that we make any material change(s), we will provide appropriate notice to you',
#  'sub6_4_score': 0.29912027878506925,
#  'sub6_4_extract': 'As part of any such integration, you may be required to accept third party terms of use and privacy policy'}
